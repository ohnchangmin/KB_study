# %%
import requests
from bs4 import BeautifulSoup
url = "https://lolchess.gg/statistics/items?hl=ko-KR"
htmlText = requests.get(url).text
bsoup = BeautifulSoup(htmlText, "html.parser")
btab = bsoup.find("tbody")
#btab = bsoup.find_all("td", {"class":"champion"})
btrs = btab.find_all("tr")
garen = btrs[0].get_text().split("\n")



# import requests
# from bs4 import BeautifulSoup

# url = 'https://lolchess.gg/statistics/items?hl=ko-KR'
# htmlText = requests.get(url).text
# bsoup = BeautifulSoup(htmlText,"html.parser")
# btab = bsoup.find("tbody")

# btemp = btab.find_all("tr")

# #print("이름: ",btemp[1].get_text().split("\n")[1])
# for item in btemp:
#     print("이름: ",item.get_text().split("\n")[7])
#     print("아이템1: ",item.get_text().split("\n")[15])
#     print("아이템1 확률: ",item.get_text().split("\n")[14])
#     print("-------------------------------------------------------")

# %%
garen
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '가렌',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '8.68%',
#  '워모그의 갑옷',
#  '',
#  '+',
#  '',
#  '8.68%',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '5.96%',
#  '태양불꽃 망토',
#  '',
#  '+',
#  '',
#  '5.96%',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '4.9%',
#  '가고일 돌갑옷',
#  '',
#  '+',
#  '',
#  '4.9%',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '4.73%',
#  '워모그의 제물 갑옷',
#  '',
#  '+',
#  '',
#  '4.73%',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '4.57%',
#  '거인의 결의',
#  '',
#  '+',
#  '',
#  '4.57%',
#  '',
#  '',
#  '']
