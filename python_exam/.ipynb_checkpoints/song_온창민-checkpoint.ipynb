# %%
post = '''신촌을 못가 한번을 못가
혹시 너와 마주칠까 봐
널 보면 눈물이 터질까 봐
친구들 한잔 하자고
또 꼬시며 불러대도
난 안가 아니 죽어도 못가
자주 갔었던 좋아했었던
사거리 그 포장마차가
그립다 니가 너무 그립다
새빨개진 그 얼굴로
날 사랑한다 했었던
그곳엘 내가 어떻게 가니
오늘 그 거리가 그리워 운다 또 운다
아직 많이 보고 싶나 봐
너도 어디선가 나 처럼 울까 또 울까
그런 너를 마주칠까 신촌을 못가
데려다 주던 아쉬워하던
막차 버스 안에서 우리
좋았지 우리 너무 좋았지
뒷자리 창가에 앉아 호
입김불며 그리던 니 이름
그리고 널 사랑해
그걸 어떻게 잊니
오늘 그 거리가 그리워 운다 또 운다
아직 많이 보고 싶나 봐
너도 어디선가 나처럼 울까 또 울까
그런 너를 마주칠까 신촌을 못가
우리 둘만 있어도 좋았잖아
종일 땀이 찼던 두 손 뜨겁던 입맞춤도
다 거기 있잖아 다 살아 있잖아
오늘 이 노래를 부른다 goodbye and goodbye
이젠 너를 놓아 줄까 봐
마지막으로 널 부른다 사랑해 널 사랑해
너를 만난 그 곳은 참 행복했었다'''

a = post.replace('\n', ' ')
a = a.replace('안가', '못가 ')
a = a.replace('널', '너를')
a = a.replace('  ', ' ')
b = a.split(' ')

#print(b)

count_list=[]
for i in b:
    count_list.append(b.count(i))
    
    
song_dic = dict(zip(b, count_list))

print(song_dic)

#행복했었다, 좋아했었던, 뜨겁던, 좋았지 등의 긍정적인 단어들은 
#모두 과거형으로 표현되고 있는 것을 보니 긍정적인 상황은 이미 지났음을 짐작할 수 있고 
#빈도 또한 낮게 나오는걸 보니 긍정적인 분위기의 노래가 아닌 듯
#가장 많이 등장하는 단어는 '너를'  추가로 너도, 너와, 니가 등과 너에 관련된 단어들이 많은 것을 보아 
#긍정적인 상황들이 너와 관련된 것들이였을 것이라고 짐작됨
#'너를'을 제외하고 많이 등장하는 단어들은 못가, 울까, 울어와 같은 -적인 단어인 것을 보아 분위기는 어두운 분위기인 노래.
# Out:
# {'신촌을': 3, '못가': 6, '한번을': 1, '혹시': 1, '너와': 1, '마주칠까': 3, '봐': 5, '너를': 8, '보면': 1, '눈물이': 1, '터질까': 1, '친구들': 1, '한잔': 1, '하자고': 1, '또': 5, '꼬시며': 1, '불러대도': 1, '난': 1, '아니': 1, '죽어도': 1, '자주': 1, '갔었던': 1, '좋아했었던': 1, '사거리': 1, '그': 5, '포장마차가': 1, '그립다': 2, '니가': 1, '너무': 2, '새빨개진': 1, '얼굴로': 1, '날': 1, '사랑한다': 1, '했었던': 1, '그곳엘': 1, '내가': 1, '어떻게': 2, '가니': 1, '오늘': 3, '거리가': 2, '그리워': 2, '운다': 4, '아직': 2, '많이': 2, '보고': 2, '싶나': 2, '너도': 2, '어디선가': 2, '나': 1, '처럼': 1, '울까': 4, '그런': 2, '데려다': 1, '주던': 1, '아쉬워하던': 1, '막차': 1, '버스': 1, '안에서': 1, '우리': 3, '좋았지': 2, '뒷자리': 1, '창가에': 1, '앉아': 1, '호': 1, '입김불며': 1, '그리던': 1, '니': 1, '이름': 1, '그리고': 1, '사랑해': 3, '그걸': 1, '잊니': 1, '나처럼': 1, '둘만': 1, '있어도': 1, '좋았잖아': 1, '종일': 1, '땀이': 1, '찼던': 1, '두': 1, '손': 1, '뜨겁던': 1, '입맞춤도': 1, '다': 2, '거기': 1, '있잖아': 2, '살아': 1, '이': 1, '노래를': 1, '부른다': 2, 'goodbye': 2, 'and': 1, '이젠': 1, '놓아': 1, '줄까': 1, '마지막으로': 1, '만난': 1, '곳은': 1, '참': 1, '행복했었다': 1}
